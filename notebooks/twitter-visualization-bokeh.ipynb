# %% [markdown]
# ![title](http://ocausal.imbv.net/wp-content/uploads/2017/02/banner-autocop-3.jpg)
# [AutoCop](http://ocausal.imbv.net/proyecto-autocop-es/), Proof of Concept of the  Observatorio de Contenidos Audiovisuales ([OCA](http://ocausal.imbv.net/proyecto-autocop-es/)), funded by the University of Salamanca Foundation [Plan TCUE 2015-2017 Fase 2].
# Principal Investigator: Carlos Arcila Calderón. Researchers: Félix Ortega, Javier Amores, Sofía Trullenque, Miguel Vicente, Mateo Álvarez, Javier Ramírez

# %% [markdown]
# # AutoCop to run in a Spark in English

# %% [markdown]
# # Twitter sentiment streaming visualization
#
# We're going to use Bokeh to visualize the output of our streaming sentiment analysis. This notebook will connect to a remote MongoDB server and poll for the latest results every given time. It will fetch the data, batch process it for visualization and plot it in a nice line chart.

# %% [markdown]
# ## Imports

# %%
import time
import numpy as np

from bokeh.models.sources import ColumnDataSource
from bokeh.plotting import figure
from bokeh.io import output_notebook, show, push_notebook

import pymongo
from datetime import datetime, timedelta
from bson.objectid import ObjectId
import pprint

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ea33c725-2081-48c7-b70f-94a7bca48486">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Global configuration

# %%
SERVER_URL = "mongodb://localhost:27017"

# %%
client = pymongo.MongoClient(SERVER_URL)
db = client.twitter
coll = db.labels

# %% [markdown]
# ## Process Mongo data for visualization
#
# The processing scripts process batches of tweets and write to the database in batches too.
#
# From our side, we're fetching batches of processed tweets of the form:
#
# ```
#     {'_id': ObjectId('5900f5bda822ec58140eae67'),
#      'in_batch_id': 3,
#      'label': -1,
#      'timestamp': datetime.datetime(2017, 4, 26, 17, 32, 12, 60000)}
# ```
#
# Where:
#
# | Field        | Description                                                                         |
# |--------------|-------------------------------------------------------------------------------------|
# | `_id`        | Unique ID auto generated by MongoDB                                                 |
# | ìn_batch_id` | Position of the result within the processed batch (not very relevant)               |
# | `label`      | Either 1 or -1. 1 means the processed tweet was positive, -1 means it was negative. |
# | `timestamp`  | Time at which the tweet was processed and written into the database                 |
#
# We're just taking all `label`s in every batch and adding the `-1` and `+1` together to get the batch net score.

# %%
def compute_batch_score(batch):
    score = 0
    for result in batch:
        score = score + result["label"] # todo: rename variable for actual variable
    return score

# %% [markdown]
# ## Visualization
#
# Configurable parameters:
#
# `period`: time in seconds to wait to poll the database for the next batch
#
# `n_show`: number of points that will be shown simoulstaneously on screen
#
#
# How it works: we create a Bokeh `figure` and we add a `line` to it. Inside an infinite loop, we poll for a new batch, advance one step, calculate the current y value (batch score), stream the data for Bokeh to update the chart and sleep for `period` seconds.
#
# As you will notice, this cell will run until manually stopped, avoiding any other cells to execute in the meanwhile.

# %%
source = ColumnDataSource(dict(x=[], y=[]))

my_figure = figure(plot_width=800, plot_height=400)
my_figure.line(source=source, x="x", y="y", line_width=2, alpha=.85, color='blue')

handle = show(my_figure, notebook_handle=True)

new_data = dict(x=[0], y=[0])

x = []
y = []

step = 0
period = 2  # in seconds
n_show = 300  # number of points to keep and show

timenow = datetime.utcnow() - timedelta(hours=2, seconds=10)

while True:
    batch = coll.find({'timestamp':{'$gt': timenow}}).sort([("timestamp", -1)])
    
    latest_value = new_data['y'][0]
    
    new_data = dict(x=[step], y=[latest_value + compute_batch_score(batch)])

    source.stream(new_data, n_show)

    push_notebook(handle=handle)
    step += 1

    timenow = datetime.utcnow() - timedelta(hours=2, seconds=10)
    time.sleep(period)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ff6f74c8-d9f1-481c-b3f5-9c7fd3dff5cf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ff6f74c8-d9f1-481c-b3f5-9c7fd3dff5cf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a3be24fd-ba52-43d4-8d53-e0ef1c6eef4b", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ff6f74c8-d9f1-481c-b3f5-9c7fd3dff5cf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ff6f74c8-d9f1-481c-b3f5-9c7fd3dff5cf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1725a42a-914f-4aa0-b5ba-5fda47fc1b79":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.85},"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"77241d28-1dd5-4139-a77e-08a972ae484a","type":"Line"},{"attributes":{"below":[{"id":"eb416c15-6b64-4f33-8a69-07a59b8a8df4","type":"LinearAxis"}],"left":[{"id":"f99ee276-6620-4314-a014-5655b6c05a96","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"eb416c15-6b64-4f33-8a69-07a59b8a8df4","type":"LinearAxis"},{"id":"4269874a-fd45-463b-ab39-f16b87b5f2f7","type":"Grid"},{"id":"f99ee276-6620-4314-a014-5655b6c05a96","type":"LinearAxis"},{"id":"27e10483-7a8f-4858-8855-7255f5b05a59","type":"Grid"},{"id":"9a37d7c8-e204-42c9-bd0d-ef782e6d0607","type":"BoxAnnotation"},{"id":"b9ad95d3-e545-457a-99d2-57d91328bf45","type":"GlyphRenderer"}],"title":{"id":"1167c8b5-b2f4-4b6d-8d82-21d227183952","type":"Title"},"tool_events":{"id":"a1fa26e2-887a-4fd0-850a-5a02d1063aff","type":"ToolEvents"},"toolbar":{"id":"98b04703-8d99-4484-9548-50c89c44f2ad","type":"Toolbar"},"x_range":{"id":"dc37662a-c775-4466-ad72-7d7df878ba0d","type":"DataRange1d"},"y_range":{"id":"c407514e-8a1d-44a0-beb1-3df19eed3860","type":"DataRange1d"}},"id":"76deacd9-7601-4faa-985e-7ac21555f29f","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"76deacd9-7601-4faa-985e-7ac21555f29f","subtype":"Figure","type":"Plot"},"ticker":{"id":"9ba1c37d-1e68-4a0c-b61e-f5622fa806eb","type":"BasicTicker"}},"id":"27e10483-7a8f-4858-8855-7255f5b05a59","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b8151c97-5d55-469b-af5d-d6c540094e4a","type":"PanTool"},{"id":"65d4639a-6401-455f-91fb-4f2c2173e2f7","type":"WheelZoomTool"},{"id":"ffc1d34c-4cf3-4f91-b92a-783676f1fdb3","type":"BoxZoomTool"},{"id":"72e53e4e-3d7b-4253-ba1d-8b094e80c9ca","type":"SaveTool"},{"id":"a0feb90f-7137-418b-831e-10e3b125b28d","type":"ResetTool"},{"id":"0a8923a3-deb0-4bbc-8d62-41e30eae72ab","type":"HelpTool"}]},"id":"98b04703-8d99-4484-9548-50c89c44f2ad","type":"Toolbar"},{"attributes":{},"id":"9ba1c37d-1e68-4a0c-b61e-f5622fa806eb","type":"BasicTicker"},{"attributes":{"data_source":{"id":"fb7035d3-c5ec-4472-b801-c6ea9acd0e09","type":"ColumnDataSource"},"glyph":{"id":"77241d28-1dd5-4139-a77e-08a972ae484a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"53f45a39-2292-4e8f-a621-753d1b17eb16","type":"Line"},"selection_glyph":null},"id":"b9ad95d3-e545-457a-99d2-57d91328bf45","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"3bd79c74-3573-4f38-8e86-112c3b5ca770","type":"BasicTickFormatter"},"plot":{"id":"76deacd9-7601-4faa-985e-7ac21555f29f","subtype":"Figure","type":"Plot"},"ticker":{"id":"9ba1c37d-1e68-4a0c-b61e-f5622fa806eb","type":"BasicTicker"}},"id":"f99ee276-6620-4314-a014-5655b6c05a96","type":"LinearAxis"},{"attributes":{},"id":"a1fa26e2-887a-4fd0-850a-5a02d1063aff","type":"ToolEvents"},{"attributes":{"plot":{"id":"76deacd9-7601-4faa-985e-7ac21555f29f","subtype":"Figure","type":"Plot"}},"id":"72e53e4e-3d7b-4253-ba1d-8b094e80c9ca","type":"SaveTool"},{"attributes":{},"id":"ecfd7133-fd18-40b1-98bb-4fdde6230681","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"9a37d7c8-e204-42c9-bd0d-ef782e6d0607","type":"BoxAnnotation"},"plot":{"id":"76deacd9-7601-4faa-985e-7ac21555f29f","subtype":"Figure","type":"Plot"}},"id":"ffc1d34c-4cf3-4f91-b92a-783676f1fdb3","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"1167c8b5-b2f4-4b6d-8d82-21d227183952","type":"Title"},{"attributes":{"formatter":{"id":"ecfd7133-fd18-40b1-98bb-4fdde6230681","type":"BasicTickFormatter"},"plot":{"id":"76deacd9-7601-4faa-985e-7ac21555f29f","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad21e053-d0b2-4715-bb33-91dc62d29d72","type":"BasicTicker"}},"id":"eb416c15-6b64-4f33-8a69-07a59b8a8df4","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[],"y": ...
